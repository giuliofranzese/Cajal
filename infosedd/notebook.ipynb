# %% [markdown]
# # InfoSEDD: Information-theoretic Synergy/Redundancy Decomposition
#
# Interactive notebook for exploring partial information decomposition (PID) with neural estimators.
#
# **Topics covered:**
# - Redundancy, synergy, and unique information
# - The redundancy lattice
# - Neural estimation of PID components
# - Benchmarks on synthetic data
# - Application to biological data

# %%
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

torch.manual_seed(42)
np.random.seed(42)

# %% [markdown]
# ## 1. Synthetic Data Generation
#
# We start with discrete gate examples (AND, OR, XOR) where the PID ground truth is known analytically.

# %%
# TODO: implement gate data generators
def generate_and_gate(n_samples=1000):
    x1 = np.random.randint(0, 2, n_samples)
    x2 = np.random.randint(0, 2, n_samples)
    y = (x1 & x2).astype(int)
    return x1, x2, y

x1, x2, y = generate_and_gate()
print(f"AND gate: x1={x1[:5]}, x2={x2[:5]}, y={y[:5]}")

# %% [markdown]
# ## 2. InfoSEDD Estimator
#
# Implement the neural network estimator for PID components.

# %%
# TODO: implement InfoSEDD estimator
pass

# %% [markdown]
# ## 3. Biological Application
#
# Apply InfoSEDD to single-cell multimodal data.

# %%
# TODO: load and preprocess single-cell data
pass
